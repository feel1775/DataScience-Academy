# %%
import numpy as np

# %%
import scipy as sp
import pandas as pd

# %%
data = pd.read_csv('data01_iris.csv')

# %%
data
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %%
data.shape
# Out:
# (150, 5)

# %%
# %matplotlib inline

# %%
data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001203FB8E668>,
# ...
#       dtype=object)

# %%
data.boxplot()

# %%
data.plot()

# %%
v = data['Sepal.Length']

# %%
v
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
# 5      5.4
# 6      4.6
# 7      5.0
# 8      4.4
# 9      4.9
# 10     5.4
# 11     4.8
# 12     4.8
# 13     4.3
# 14     5.8
# 15     5.7
# 16     5.4
# 17     5.1
# 18     5.7
# 19     5.1
# 20     5.4
# 21     5.1
# 22     4.6
# 23     5.1
# 24     4.8
# 25     5.0
# 26     5.0
# 27     5.2
# 28     5.2
# 29     4.7
#       ...
# 120    6.9
# 121    5.6
# 122    7.7
# 123    6.3
# 124    6.7
# 125    7.2
# 126    6.2
# 127    6.1
# 128    6.4
# 129    7.2
# 130    7.4
# 131    7.9
# 132    6.4
# 133    6.3
# 134    6.1
# 135    7.7
# 136    6.3
# 137    6.4
# 138    6.0
# 139    6.9
# 140    6.7
# 141    6.9
# 142    5.8
# 143    6.8
# 144    6.7
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: Sepal.Length, Length: 150, dtype: float64

# %%
type(v)
# Out:
# pandas.core.series.Series

# %%
a = data[['Sepal.Length']]

# %%
a
# Out:
#      Sepal.Length
# 0             5.1
# 1             4.9
# 2             4.7
# 3             4.6
# 4             5.0
# 5             5.4
# 6             4.6
# 7             5.0
# 8             4.4
# 9             4.9
# 10            5.4
# 11            4.8
# 12            4.8
# 13            4.3
# 14            5.8
# 15            5.7
# 16            5.4
# 17            5.1
# 18            5.7
# 19            5.1
# 20            5.4
# 21            5.1
# 22            4.6
# 23            5.1
# 24            4.8
# 25            5.0
# 26            5.0
# 27            5.2
# 28            5.2
# 29            4.7
# ..            ...
# 120           6.9
# 121           5.6
# 122           7.7
# 123           6.3
# 124           6.7
# 125           7.2
# 126           6.2
# 127           6.1
# 128           6.4
# 129           7.2
# 130           7.4
# 131           7.9
# 132           6.4
# 133           6.3
# 134           6.1
# 135           7.7
# 136           6.3
# 137           6.4
# ...

# %%
b = data['Sepal.Length']

# %%
b
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
# 5      5.4
# 6      4.6
# 7      5.0
# 8      4.4
# 9      4.9
# 10     5.4
# 11     4.8
# 12     4.8
# 13     4.3
# 14     5.8
# 15     5.7
# 16     5.4
# 17     5.1
# 18     5.7
# 19     5.1
# 20     5.4
# 21     5.1
# 22     4.6
# 23     5.1
# 24     4.8
# 25     5.0
# 26     5.0
# 27     5.2
# 28     5.2
# 29     4.7
#       ...
# 120    6.9
# 121    5.6
# 122    7.7
# 123    6.3
# 124    6.7
# 125    7.2
# 126    6.2
# 127    6.1
# 128    6.4
# 129    7.2
# 130    7.4
# 131    7.9
# 132    6.4
# 133    6.3
# 134    6.1
# 135    7.7
# 136    6.3
# 137    6.4
# 138    6.0
# 139    6.9
# 140    6.7
# 141    6.9
# 142    5.8
# 143    6.8
# 144    6.7
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: Sepal.Length, Length: 150, dtype: float64

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
type(b)
# Out:
# pandas.core.series.Series

# %%
v.sum()
# Out:
# 876.5

# %%
v.var()
# Out:
# 0.6856935123042505

# %%
v.mean()
# Out:
# 5.843333333333335

# %%
idx = data['Sepal.Length']>5.8

# %%
idx.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Sepal.Length, dtype: bool

# %%
idx2 = data[['Sepal.Length']]>5.8

# %%
idx2.head()
# Out:
#    Sepal.Length
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False

# %%
d = data[idx]

# %%
d.shape
# Out:
# (70, 5)

# %%
d.head(5)
# Out:
#     Sepal.Length  Sepal.Width  Petal.Length  Petal.Width     Species
# 50           7.0          3.2           4.7          1.4  versicolor
# 51           6.4          3.2           4.5          1.5  versicolor
# 52           6.9          3.1           4.9          1.5  versicolor
# 54           6.5          2.8           4.6          1.5  versicolor
# 56           6.3          3.3           4.7          1.6  versicolor

# %%
idx = (data['Sepal.Length'] > 5.8) & (data['Species']=='versicolor')

# %%
d2 = data[idx]

# %%
d2.head()
# Out:
#     Sepal.Length  Sepal.Width  Petal.Length  Petal.Width     Species
# 50           7.0          3.2           4.7          1.4  versicolor
# 51           6.4          3.2           4.5          1.5  versicolor
# 52           6.9          3.1           4.9          1.5  versicolor
# 54           6.5          2.8           4.6          1.5  versicolor
# 56           6.3          3.3           4.7          1.6  versicolor

# %%
type(d2)
# Out:
# pandas.core.frame.DataFrame

# %%
idx = (data['Petal.Length']>data['Petal.Length'].median())&(data['Species']=='virginica')

# %%
data.median()
# Out:
# Sepal.Length    5.80
# Sepal.Width     3.00
# Petal.Length    4.35
# Petal.Width     1.30
# dtype: float64

# %%
d3 = data[idx]

# %%
data.mean()
# Out:
# Sepal.Length    5.843333
# Sepal.Width     3.057333
# Petal.Length    3.758000
# Petal.Width     1.199333
# dtype: float64

# %%
d3.shape
# Out:
# (50, 5)

# %%
d3.plot()

# %%
d3.boxplot()

# %%
d4 = data.iloc[:5,:2]

# %%
d4.head(5)
# Out:
#    Sepal.Length  Sepal.Width
# 0           5.1          3.5
# 1           4.9          3.0
# 2           4.7          3.2
# 3           4.6          3.1
# 4           5.0          3.6

# %%
d4.shape
# Out:
# (5, 2)

# %%
d4.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-8a3283982069> in <module>
# ----> 1 d4.shape()
#
# TypeError: 'tuple' object is not callable

# %%
data.plot()

# %%
d5 = data[:5,:-2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-07b588505091> in <module>
# ----> 1 d5 = data[:5,:-2]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
# ...

# %%
v
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
# 5      5.4
# 6      4.6
# 7      5.0
# 8      4.4
# 9      4.9
# 10     5.4
# 11     4.8
# 12     4.8
# 13     4.3
# 14     5.8
# 15     5.7
# 16     5.4
# 17     5.1
# 18     5.7
# 19     5.1
# 20     5.4
# 21     5.1
# 22     4.6
# 23     5.1
# 24     4.8
# 25     5.0
# 26     5.0
# 27     5.2
# 28     5.2
# 29     4.7
#       ...
# 120    6.9
# 121    5.6
# 122    7.7
# 123    6.3
# 124    6.7
# 125    7.2
# 126    6.2
# 127    6.1
# 128    6.4
# 129    7.2
# 130    7.4
# 131    7.9
# 132    6.4
# 133    6.3
# 134    6.1
# 135    7.7
# 136    6.3
# 137    6.4
# 138    6.0
# 139    6.9
# 140    6.7
# 141    6.9
# 142    5.8
# 143    6.8
# 144    6.7
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: Sepal.Length, Length: 150, dtype: float64

# %%
data['SL2'] = v

# %%
data.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species  SL2
# 0           5.1          3.5           1.4          0.2  setosa  5.1
# 1           4.9          3.0           1.4          0.2  setosa  4.9
# 2           4.7          3.2           1.3          0.2  setosa  4.7
# 3           4.6          3.1           1.5          0.2  setosa  4.6
# 4           5.0          3.6           1.4          0.2  setosa  5.0

# %%
data['SL2'] = v**2

# %%
data.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species    SL2
# 0           5.1          3.5           1.4          0.2  setosa  26.01
# 1           4.9          3.0           1.4          0.2  setosa  24.01
# 2           4.7          3.2           1.3          0.2  setosa  22.09
# 3           4.6          3.1           1.5          0.2  setosa  21.16
# 4           5.0          3.6           1.4          0.2  setosa  25.00

# %%
d2 = data.sort_values(by=['Sepal.Length'])
d3 = data.sort_values(by=['Sepal.Length'],ascending=False)

# %%
d2
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width     Species    SL2
# 13            4.3          3.0           1.1          0.1      setosa  18.49
# 42            4.4          3.2           1.3          0.2      setosa  19.36
# 38            4.4          3.0           1.3          0.2      setosa  19.36
# 8             4.4          2.9           1.4          0.2      setosa  19.36
# 41            4.5          2.3           1.3          0.3      setosa  20.25
# 22            4.6          3.6           1.0          0.2      setosa  21.16
# 3             4.6          3.1           1.5          0.2      setosa  21.16
# 6             4.6          3.4           1.4          0.3      setosa  21.16
# 47            4.6          3.2           1.4          0.2      setosa  21.16
# 2             4.7          3.2           1.3          0.2      setosa  22.09
# 29            4.7          3.2           1.6          0.2      setosa  22.09
# ...

# %%
d3
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width     Species    SL2
# 131           7.9          3.8           6.4          2.0   virginica  62.41
# 135           7.7          3.0           6.1          2.3   virginica  59.29
# 122           7.7          2.8           6.7          2.0   virginica  59.29
# 117           7.7          3.8           6.7          2.2   virginica  59.29
# 118           7.7          2.6           6.9          2.3   virginica  59.29
# 105           7.6          3.0           6.6          2.1   virginica  57.76
# 130           7.4          2.8           6.1          1.9   virginica  54.76
# 107           7.3          2.9           6.3          1.8   virginica  53.29
# 125           7.2          3.2           6.0          1.8   virginica  51.84
# 109           7.2          3.6           6.1          2.5   virginica  51.84
# 129           7.2          3.0           5.8          1.6   virginica  51.84
# ...

# %%
d2 = data.sort_values(by=['Sepal.Length','Petal.Width'])

# %%
d2
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width     Species    SL2
# 13            4.3          3.0           1.1          0.1      setosa  18.49
# 8             4.4          2.9           1.4          0.2      setosa  19.36
# 38            4.4          3.0           1.3          0.2      setosa  19.36
# 42            4.4          3.2           1.3          0.2      setosa  19.36
# 41            4.5          2.3           1.3          0.3      setosa  20.25
# 3             4.6          3.1           1.5          0.2      setosa  21.16
# 22            4.6          3.6           1.0          0.2      setosa  21.16
# 47            4.6          3.2           1.4          0.2      setosa  21.16
# 6             4.6          3.4           1.4          0.3      setosa  21.16
# 2             4.7          3.2           1.3          0.2      setosa  22.09
# 29            4.7          3.2           1.6          0.2      setosa  22.09
# ...

# %%
for i in range(data.shape[1]):
    v=data.iloc[:,i]
    if type(v[0]) != type('str'):
            print(i,v.mean())
# Out:
# 0 5.843333333333335
# 1 3.057333333333334
# 2 3.7580000000000027
# 3 1.199333333333334
# 5 34.82566666666665

# %%
v.head()
# Out:
# 0    setosa
# 1    setosa
# 2    setosa
# 3    setosa
# 4    setosa
# Name: Species, dtype: object

# %%
data.shape[1]
# Out:
# 6

# %%
d6 = data.shape[1]

# %%
d6
# Out:
# 6

# %%
data2 = pd.read_csv('data02_college.csv')

# %%
data2.shape
# Out:
# (777, 19)

# %%
data2.head()
# Out:
#                      University Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %%
v1=data2['University']

# %%
v1.shape
# Out:
# (777,)

# %%
v1.isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 747    False
# 748    False
# 749    False
# 750    False
# 751    False
# 752    False
# 753    False
# 754    False
# 755    False
# 756    False
# 757    False
# 758    False
# 759    False
# 760    False
# 761    False
# 762    False
# 763    False
# 764    False
# 765    False
# 766    False
# 767    False
# 768    False
# 769    False
# 770    False
# 771    False
# 772    False
# 773    False
# 774    False
# 775    False
# 776    False
# Name: University, Length: 777, dtype: bool

# %%
v2=[v1.isnull()]

# %%
v2.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-84-5fca9e431bb0> in <module>
# ----> 1 v2.shape
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
v2=data2[v1.isnull()]

# %%
v2.head()
# Out:
# Empty DataFrame
# Columns: [University, Private, Apps, Accept, Enroll, Top10perc, Top25perc, F.Undergrad, P.Undergrad, Outstate, Room.Board, Books, Personal, PhD, Terminal, S.F.Ratio, perc.alumni, Expend, Grad.Rate]
# Index: []

# %%
v2
# Out:
# Empty DataFrame
# Columns: [University, Private, Apps, Accept, Enroll, Top10perc, Top25perc, F.Undergrad, P.Undergrad, Outstate, Room.Board, Books, Personal, PhD, Terminal, S.F.Ratio, perc.alumni, Expend, Grad.Rate]
# Index: []

# %%
v2=data2[v1.notnull()]

# %%
v2.count()
# Out:
# University     777
# Private        777
# Apps           777
# Accept         777
# Enroll         777
# Top10perc      777
# Top25perc      777
# F.Undergrad    777
# P.Undergrad    777
# Outstate       777
# Room.Board     777
# Books          777
# Personal       777
# PhD            777
# Terminal       777
# S.F.Ratio      777
# perc.alumni    777
# Expend         777
# Grad.Rate      777
# dtype: int64

# %%
v2.shape
# Out:
# (777, 19)

# %%
v2.groupby(['Private'])['Expend'].mean()
# Out:
# Private
# No      7458.316038
# Yes    10486.353982
# Name: Expend, dtype: float64

# %%
v2.sort_values(by=['Top10perc'],ascending=False)[:10]
# Out:
#                                 University Private   Apps  Accept  Enroll  \
# 354  Massachusetts Institute of Technology     Yes   6411    2140    1078
# 605   University of California at Berkeley      No  19873    8252    3215
# 251                    Harvey Mudd College     Yes   1377     572     178
# 775                        Yale University     Yes  10705    2453    1317
# 174                        Duke University     Yes  13789    3893    1583
# 459                   Princeton University     Yes  13218    2042    1153
# 250                     Harvard University     Yes  13865    2165    1606
# 222        Georgia Institute of Technology      No   7837    4527    2276
# 158                      Dartmouth College     Yes   8587    2273    1087
# 70                        Brown University     Yes  12586    3239    1462
#
#      Top10perc  Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  \
# 354         96         99         4481           28     20100        5975
# ...

# %%
accR = v2['Accept']/v2['Apps']

# %%
v2['accR'] = accR

# %%
v2.sort_values(by=['accR'])[:10]
# Out:
#                 University Private   Apps  Accept  Enroll  Top10perc  \
# 459   Princeton University     Yes  13218    2042    1153         90
# 250     Harvard University     Yes  13865    2165    1606         90
# 775        Yale University     Yes  10705    2453    1317         95
# 16         Amherst College     Yes   4302     992     418         83
# 70        Brown University     Yes  12586    3239    1462         87
# 221  Georgetown University     Yes  11115    2881    1390         71
# 158      Dartmouth College     Yes   8587    2273    1087         87
# 174        Duke University     Yes  13789    3893    1583         90
# 144    Columbia University     Yes   6756    1930     871         78
# 763       Williams College     Yes   4186    1245     526         81
#
#      Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  \
# 459         98         4540          146     19900        5910    675
# ...

# %%
v2.plot()

# %%
v2.scatter()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-116-61e14324edf1> in <module>
# ----> 1 v2.scatter()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'scatter'

# %%
pd.scatter_matrix(v2,alpha=0.2)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated, use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001204193AA20>,
# ...
#       dtype=object)

# %%
ax = v2[v2['Private']=='Yes'].plot.scatter(x='Outstate', y='Expend', color='red',label='Private')
v2[v2['Private']!='Yes'].plot.scatter(x='Outstate', y='Expend', color='blue',label='Public',ax=ax)
